# %%
# !pip install vizdoom
# Out:
# Requirement already satisfied: vizdoom in .\env\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy in .\env\lib\site-packages (from vizdoom) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.0 in .\env\lib\site-packages (from vizdoom) (0.29.1)
# Requirement already satisfied: pygame>=2.1.3 in .\env\lib\site-packages (from vizdoom) (2.6.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in .\env\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in .\env\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in .\env\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in .\env\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (8.2.0)
# Requirement already satisfied: zipp>=0.5 in .\env\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.28.0->vizdoom) (3.19.2)

# %%
# !cd github & git clone https://github.com/Farama-Foundation/ViZDoom
# Out:
# fatal: destination path 'ViZDoom' already exists and is not an empty directory.

# %%
# Import vizdoom for game env
from vizdoom import *
# Import random for action sampling
import random
# Import time for sleeping
import time
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('github/ViZDoom/scenarios/defend_the_center.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([ 26., 100.])

# %%
# Loop through episodes
episodes = 10
for episode in range(episodes):
    # Create a new episode or game
    game.new_episode()
    # Check the game isn't done
    while not game.is_episode_finished():
        # Get the game state
        state = game.get_state()
        # Get the game image
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions), 4)
        # Print reward
        print('reward: ', reward)
        time.sleep(0.02)
    print('Result: ', game.get_total_reward())
    time.sleep(2)
# Out:
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  -1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  -1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  -1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  2.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0

# %%
game.close()

# %% [markdown]
# ## 2. Converting it to a Gym Environment

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in .\env\lib\site-packages (0.26.1)
# Requirement already satisfied: numpy>=1.18.0 in .\env\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in .\env\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in .\env\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in .\env\lib\site-packages (from gym) (8.2.0)
# Requirement already satisfied: zipp>=0.5 in .\env\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.19.2)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in .\env\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in .\env\lib\site-packages (from opencv-python) (1.26.4)

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces
from gym.spaces import Discrete, Box
# Import opencv
import cv2

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env):
    # Function that is called when we start the env
    def __init__(self, render=False):
        # Inherit from Env
        super().__init__()
        # Setup the game
        self.game = DoomGame()
        self.game.load_config('github/ViZDoom/scenarios/defend_the_center.cfg')

        # Render frame logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # Start the game
        self.game.init()

        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype=np.uint8)
        self.action_space = Discrete(3)
    
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) # 4 here is the frameskip parameter which makes the game run faster

        # Get all the other stuff we need to return
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0

        info = {'info': info}
        done = self.game.is_episode_finished()

        return state, reward, done, info
        
    # Define how to render the game or environment
    def render():
        pass

    # What happens when we start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state

    # Call to close down the game
    def close(self):
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %%
env.step(2)
# Out:
# (array([[[ 5],
#          [10],
#          [ 7],
#          ...,
#          [ 4],
#          [ 6],
#          [10]],
#
#         [[ 3],
#          [ 3],
#          [ 4],
#          ...,
#          [ 5],
#          [ 3],
#          [ 7]],
#
#         [[11],
#          [ 7],
#          [10],
#          ...,
#          [ 9],
#          [ 6],
#          [ 6]],
#
#         ...,
#
#         [[75],
#          [63],
#          [62],
#          ...,
#          [44],
#          [71],
#          [60]],
#
#         [[15],
#          [48],
#          [47],
#          ...,
#          [49],
#          [69],
#          [47]],
#
#         [[22],
#          [14],
#          [26],
#          ...,
#          [57],
#          [37],
#          [39]]], dtype=uint8),
#  0.0,
#  False,
#  {'info': 26.0})

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
# env_checker.check_env(env)

# %% [markdown]
# ## 3. View State

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# ## 4. Setup Callback

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in .\env\lib\site-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in .\env\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in .\env\lib\site-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in .\env\lib\site-packages (from stable-baselines3[extra]) (2.4.0+cu118)
# Requirement already satisfied: cloudpickle in .\env\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in .\env\lib\site-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in .\env\lib\site-packages (from stable-baselines3[extra]) (3.9.1)
# Requirement already satisfied: opencv-python in .\env\lib\site-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in .\env\lib\site-packages (from stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: tensorboard>=2.9.1 in .\env\lib\site-packages (from stable-baselines3[extra]) (2.17.0)
# Requirement already satisfied: psutil in .\env\lib\site-packages (from stable-baselines3[extra]) (6.0.0)
# Requirement already satisfied: tqdm in .\env\lib\site-packages (from stable-baselines3[extra]) (4.66.5)
# Requirement already satisfied: rich in .\env\lib\site-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: shimmy~=1.3.0 in .\env\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pillow in .\env\lib\site-packages (from stable-baselines3[extra]) (10.4.0)
# Requirement already satisfied: autorom~=0.6.1 in .\env\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in .\env\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in .\env\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: AutoROM.accept-rom-license in .\env\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in .\env\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in .\env\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in .\env\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (8.2.0)
# Requirement already satisfied: ale-py~=0.8.1 in .\env\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.65.4)
# Requirement already satisfied: markdown>=2.6.8 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.4)
# Requirement already satisfied: setuptools>=41.0.0 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (72.1.0)
# Requirement already satisfied: six>1.9 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in .\env\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: filelock in .\env\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.15.4)
# Requirement already satisfied: sympy in .\env\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.0)
# Requirement already satisfied: networkx in .\env\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in .\env\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in .\env\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in .\env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in .\env\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in .\env\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\env\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\env\lib\site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: colorama in .\env\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in .\env\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\env\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in .\env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\env\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\env\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\env\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\env\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\env\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in .\env\lib\site-packages (2.4.0+cu118)
# Requirement already satisfied: torchvision in .\env\lib\site-packages (0.19.0+cu118)
# Requirement already satisfied: torchaudio in .\env\lib\site-packages (2.4.0+cu118)
# Requirement already satisfied: filelock in .\env\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in .\env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in .\env\lib\site-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in .\env\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in .\env\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in .\env\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in .\env\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in .\env\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\env\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\env\lib\site-packages (from sympy->torch) (1.3.0)

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train_dqn/train_defend'
LOG_DIR = './logs_dqn/log_defend'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ## 5. Train Gym

# %%
# Import ppo for training 
from stable_baselines3 import DQN

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = DQN(
    'CnnPolicy', 
    env, 
    tensorboard_log=LOG_DIR, 
    verbose=1, 
    learning_rate=0.0001,             # Stable learning rate for gradual improvement
    buffer_size=100000,               # Large enough to handle diverse experience
    learning_starts=1000,             # Ensure learning starts after some initial exploration
    batch_size=32,                    # Suitable batch size for balanced updates
    tau=1.0,                          # Hard updates (for stability)
    gamma=0.99,                       # Standard discount for future rewards
    train_freq=4,                     # Train after every 4 steps
    gradient_steps=1,                 # One gradient step per update
    target_update_interval=5000,      # Moderate update frequency for target network stability
    exploration_fraction=0.2,         # Explore 20% of the time to encourage diverse actions
    exploration_initial_eps=1.0,      # Start with fully random exploration
    exploration_final_eps=0.05,       # Reduce randomness over time
    max_grad_norm=10,                 # Gradient clipping for stability
    optimize_memory_usage=False       # Keep memory usage optimization off to avoid errors
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# C:\projects\shradha-doom\env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\projects\shradha-doom\env\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 3.20GB > 2.49GB
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs_dqn/log_defend\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.8     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 79       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 319      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | -0.125   |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 91       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 628      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | 0.0833   |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 97       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | 0.188    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 49       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1297     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.55e-05 |
# |    n_updates        | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 36       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 1671     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.2     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 32       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 1926     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.76e-05 |
# |    n_updates        | 231      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.9     |
# |    ep_rew_mean      | 0.179    |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 29       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 2237     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79       |
# |    ep_rew_mean      | 0.156    |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 27       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 2529     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.8     |
# |    ep_rew_mean      | 0.194    |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 26       |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 2872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000434 |
# |    n_updates        | 467      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.4     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 25       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 3137     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.6     |
# |    ep_rew_mean      | 0.0909   |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 24       |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 3416     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 603      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.8     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 24       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 3732     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 682      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.2     |
# |    ep_rew_mean      | 0.212    |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 23       |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 4067     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000318 |
# |    n_updates        | 766      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.3     |
# |    ep_rew_mean      | 0.179    |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 22       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 4385     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00483  |
# |    n_updates        | 846      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.2     |
# |    ep_rew_mean      | 0.267    |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 21       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 4753     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000286 |
# |    n_updates        | 938      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.9     |
# |    ep_rew_mean      | 0.219    |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 21       |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 5047     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000345 |
# |    n_updates        | 1011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.8     |
# |    ep_rew_mean      | 0.279    |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 21       |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 5425     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 1106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.4     |
# |    ep_rew_mean      | 0.319    |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 20       |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 5791     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000966 |
# |    n_updates        | 1197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | 0.382    |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 20       |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 6155     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 1288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | 0.375    |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 19       |
# |    time_elapsed     | 338      |
# |    total_timesteps  | 6489     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000598 |
# |    n_updates        | 1372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | 0.429    |
# |    exploration_rate | 0.672    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 18       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 6914     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 1478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.2     |
# |    ep_rew_mean      | 0.443    |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 18       |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 7230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 1557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | 0.457    |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 18       |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 7568     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 1641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.6     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 18       |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 7933     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 1733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83       |
# |    ep_rew_mean      | 0.53     |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 17       |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 8298     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 1824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | 0.59     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 17       |
# |    time_elapsed     | 491      |
# |    total_timesteps  | 8702     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 1925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.5     |
# |    ep_rew_mean      | 0.68     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 17       |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 9083     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 2020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | 0.7      |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 17       |
# |    time_elapsed     | 537      |
# |    total_timesteps  | 9427     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 2106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | 0.7      |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 17       |
# |    time_elapsed     | 556      |
# |    total_timesteps  | 9755     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 2188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.4     |
# |    ep_rew_mean      | 0.73     |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 17       |
# |    time_elapsed     | 577      |
# |    total_timesteps  | 10109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 2277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.3     |
# |    ep_rew_mean      | 0.83     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 17       |
# |    time_elapsed     | 603      |
# |    total_timesteps  | 10560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | 0.83     |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 17       |
# |    time_elapsed     | 621      |
# |    total_timesteps  | 10856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 2463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 17       |
# |    time_elapsed     | 649      |
# |    total_timesteps  | 11315    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00447  |
# |    n_updates        | 2578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.444    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 17       |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 11714    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 2678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 17       |
# |    time_elapsed     | 694      |
# |    total_timesteps  | 12068    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0494   |
# |    n_updates        | 2766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 17       |
# |    time_elapsed     | 718      |
# |    total_timesteps  | 12487    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00403  |
# |    n_updates        | 2871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 17       |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 12932    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 2982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 17       |
# |    time_elapsed     | 772      |
# |    total_timesteps  | 13343    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 3085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 16       |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 13764    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 3190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 16       |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 14097    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0026   |
# |    n_updates        | 3274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 16       |
# |    time_elapsed     | 869      |
# |    total_timesteps  | 14468    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0482   |
# |    n_updates        | 3366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 16       |
# |    time_elapsed     | 892      |
# |    total_timesteps  | 14775    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 3443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | 1.61     |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 16       |
# |    time_elapsed     | 938      |
# |    total_timesteps  | 15241    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 3560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | 1.69     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 15       |
# |    time_elapsed     | 989      |
# |    total_timesteps  | 15668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00404  |
# |    n_updates        | 3666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.3     |
# |    ep_rew_mean      | 1.9      |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 15       |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 16221    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 3805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | 1.96     |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 15       |
# |    time_elapsed     | 1095     |
# |    total_timesteps  | 16600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00598  |
# |    n_updates        | 3899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | 2.02     |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 14       |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 16926    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00319  |
# |    n_updates        | 3981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | 2.28     |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 14       |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 17540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00425  |
# |    n_updates        | 4134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 2.38     |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 14       |
# |    time_elapsed     | 1247     |
# |    total_timesteps  | 18009    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000991 |
# |    n_updates        | 4252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 2.51     |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 14       |
# |    time_elapsed     | 1295     |
# |    total_timesteps  | 18533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 4383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 2.62     |
# |    exploration_rate | 0.0969   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 14       |
# |    time_elapsed     | 1337     |
# |    total_timesteps  | 19013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 4503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 2.72     |
# |    exploration_rate | 0.0766   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 14       |
# |    time_elapsed     | 1376     |
# |    total_timesteps  | 19440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00551  |
# |    n_updates        | 4609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 14       |
# |    time_elapsed     | 1427     |
# |    total_timesteps  | 20005    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 3.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 14       |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 20547    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00526  |
# |    n_updates        | 4886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | 3.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 14       |
# |    time_elapsed     | 1504     |
# |    total_timesteps  | 21094    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00417  |
# |    n_updates        | 5023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 14       |
# |    time_elapsed     | 1535     |
# |    total_timesteps  | 21538    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00609  |
# |    n_updates        | 5134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 3.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 14       |
# |    time_elapsed     | 1579     |
# |    total_timesteps  | 22142    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 5285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | 3.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 13       |
# |    time_elapsed     | 1645     |
# |    total_timesteps  | 22864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00382  |
# |    n_updates        | 5465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | 4.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 13       |
# |    time_elapsed     | 1693     |
# |    total_timesteps  | 23413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00342  |
# |    n_updates        | 5603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | 4.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 13       |
# |    time_elapsed     | 1728     |
# |    total_timesteps  | 23978    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0094   |
# |    n_updates        | 5744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 4.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 13       |
# |    time_elapsed     | 1769     |
# |    total_timesteps  | 24546    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 5886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 4.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 13       |
# |    time_elapsed     | 1796     |
# |    total_timesteps  | 24986    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00681  |
# |    n_updates        | 5996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 13       |
# |    time_elapsed     | 1826     |
# |    total_timesteps  | 25402    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 6100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 13       |
# |    time_elapsed     | 1859     |
# |    total_timesteps  | 25752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 6187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 5.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 13       |
# |    time_elapsed     | 1914     |
# |    total_timesteps  | 26371    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00813  |
# |    n_updates        | 6342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 5.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 13       |
# |    time_elapsed     | 1941     |
# |    total_timesteps  | 26787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 6446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 5.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 13       |
# |    time_elapsed     | 1981     |
# |    total_timesteps  | 27215    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00783  |
# |    n_updates        | 6553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 5.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 13       |
# |    time_elapsed     | 2031     |
# |    total_timesteps  | 27790    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 6697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 5.4      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 13       |
# |    time_elapsed     | 2059     |
# |    total_timesteps  | 28148    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 6786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 5.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 13       |
# |    time_elapsed     | 2117     |
# |    total_timesteps  | 28762    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 6940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | 5.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 13       |
# |    time_elapsed     | 2161     |
# |    total_timesteps  | 29281    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 7070     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 5.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 13       |
# |    time_elapsed     | 2204     |
# |    total_timesteps  | 29782    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 7195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 5.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 13       |
# |    time_elapsed     | 2239     |
# |    total_timesteps  | 30156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 7288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 5.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 13       |
# |    time_elapsed     | 2304     |
# |    total_timesteps  | 30895    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 7473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 5.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 13       |
# |    time_elapsed     | 2362     |
# |    total_timesteps  | 31405    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00882  |
# |    n_updates        | 7601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 5.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 13       |
# |    time_elapsed     | 2404     |
# |    total_timesteps  | 31976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00665  |
# |    n_updates        | 7743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | 6.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 13       |
# |    time_elapsed     | 2448     |
# |    total_timesteps  | 32555    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00567  |
# |    n_updates        | 7888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | 6.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 13       |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 33317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00315  |
# |    n_updates        | 8079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | 6.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 13       |
# |    time_elapsed     | 2544     |
# |    total_timesteps  | 33888    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00632  |
# |    n_updates        | 8221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 6.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 13       |
# |    time_elapsed     | 2592     |
# |    total_timesteps  | 34506    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 8376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 6.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 13       |
# |    time_elapsed     | 2632     |
# |    total_timesteps  | 35037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 8509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 6.61     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 13       |
# |    time_elapsed     | 2691     |
# |    total_timesteps  | 35813    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00888  |
# |    n_updates        | 8703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 13       |
# |    time_elapsed     | 2746     |
# |    total_timesteps  | 36568    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 8891     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 13       |
# |    time_elapsed     | 2786     |
# |    total_timesteps  | 37087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 9021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 13       |
# |    time_elapsed     | 2830     |
# |    total_timesteps  | 37686    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0724   |
# |    n_updates        | 9171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 13       |
# |    time_elapsed     | 2859     |
# |    total_timesteps  | 38131    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 9282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 6.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 13       |
# |    time_elapsed     | 2902     |
# |    total_timesteps  | 38785    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 9446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 13       |
# |    time_elapsed     | 2945     |
# |    total_timesteps  | 39373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 9593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 7.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 13       |
# |    time_elapsed     | 2983     |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 9749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 7.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 13       |
# |    time_elapsed     | 3010     |
# |    total_timesteps  | 40428    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 9856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 7.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 13       |
# |    time_elapsed     | 3042     |
# |    total_timesteps  | 40962    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00558  |
# |    n_updates        | 9990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 7.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 13       |
# |    time_elapsed     | 3073     |
# |    total_timesteps  | 41445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 10111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 6530     |
# |    total_timesteps  | 81480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 20119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 12       |
# |    time_elapsed     | 6580     |
# |    total_timesteps  | 82259    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 20314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 9.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 12       |
# |    time_elapsed     | 6618     |
# |    total_timesteps  | 82864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 20465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | 9.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 12       |
# |    time_elapsed     | 6657     |
# |    total_timesteps  | 83488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 20621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 9.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 12       |
# |    time_elapsed     | 6696     |
# |    total_timesteps  | 84127    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 20781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 9.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 12       |
# |    time_elapsed     | 6727     |
# |    total_timesteps  | 84622    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 20905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 12       |
# |    time_elapsed     | 6767     |
# |    total_timesteps  | 85290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 21072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 12       |
# |    time_elapsed     | 6807     |
# |    total_timesteps  | 85921    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 21230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 12       |
# |    time_elapsed     | 6854     |
# |    total_timesteps  | 86664    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 21415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 12       |
# |    time_elapsed     | 6893     |
# |    total_timesteps  | 87227    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 21556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 9.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 12       |
# |    time_elapsed     | 6931     |
# |    total_timesteps  | 87790    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0475   |
# |    n_updates        | 21697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 9.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 12       |
# |    time_elapsed     | 6983     |
# |    total_timesteps  | 88616    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 21903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 9.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 12       |
# |    time_elapsed     | 7018     |
# |    total_timesteps  | 89199    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 22049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 12       |
# |    time_elapsed     | 7049     |
# |    total_timesteps  | 89687    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 22171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 12       |
# |    time_elapsed     | 7085     |
# |    total_timesteps  | 90272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 22317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 12       |
# |    time_elapsed     | 7120     |
# |    total_timesteps  | 90834    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00929  |
# |    n_updates        | 22458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 12       |
# |    time_elapsed     | 7165     |
# |    total_timesteps  | 91537    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 22634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 12       |
# |    time_elapsed     | 7208     |
# |    total_timesteps  | 92229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 22807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 9.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 12       |
# |    time_elapsed     | 7239     |
# |    total_timesteps  | 92730    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 22932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 8.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 12       |
# |    time_elapsed     | 7275     |
# |    total_timesteps  | 93315    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00441  |
# |    n_updates        | 23078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 9.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 12       |
# |    time_elapsed     | 7316     |
# |    total_timesteps  | 93967    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00664  |
# |    n_updates        | 23241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 9.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 12       |
# |    time_elapsed     | 7346     |
# |    total_timesteps  | 94470    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0077   |
# |    n_updates        | 23367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 12       |
# |    time_elapsed     | 7391     |
# |    total_timesteps  | 95151    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 23537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 9.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 12       |
# |    time_elapsed     | 7443     |
# |    total_timesteps  | 95673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00992  |
# |    n_updates        | 23668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 8.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 12       |
# |    time_elapsed     | 7481     |
# |    total_timesteps  | 96272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 23817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 12       |
# |    time_elapsed     | 7517     |
# |    total_timesteps  | 96868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00602  |
# |    n_updates        | 23966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 12       |
# |    time_elapsed     | 7557     |
# |    total_timesteps  | 97523    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 24130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 8.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 12       |
# |    time_elapsed     | 7600     |
# |    total_timesteps  | 98214    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 24303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 8.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 12       |
# |    time_elapsed     | 7638     |
# |    total_timesteps  | 98835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 24458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 12       |
# |    time_elapsed     | 7666     |
# |    total_timesteps  | 99304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00676  |
# |    n_updates        | 24575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 8.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 12       |
# |    time_elapsed     | 7704     |
# |    total_timesteps  | 99903    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0566   |
# |    n_updates        | 24725    |
# ----------------------------------

# %% [markdown]
# ## 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disk
model = DQN.load('./train_dqn/train_defend/best_model_100000')
# Out:
# C:\projects\shradha-doom\env\lib\site-packages\stable_baselines3\common\buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 3.20GB > 1.18GB
#   warnings.warn(

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
# Out:
# C:\projects\shradha-doom\env\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\projects\shradha-doom\env\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
mean_reward
# Out:
# 12.76

# %%
for episode in range(5):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.20)
        total_reward += reward

    print('Total Reward for episode {} is {}'.format(episode, total_reward))
    time.sleep(2)
# Out:
# Total Reward for episode 0 is 17.0
# Total Reward for episode 1 is 8.0
# Total Reward for episode 2 is 5.0
# Total Reward for episode 3 is 6.0
# Total Reward for episode 4 is 8.0

# %%
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
print(f'Mean reward over 100 episodes: {mean_reward}')
# Out:
# Mean reward over 100 episodes: 12.18

# %%
episode_lengths = []
success_count = 0
rewards = []

# Define a success threshold (e.g., 10 as an example; adjust based on your environment)
success_threshold = 7

for episode in range(100):
    obs = env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward
        steps += 1

    episode_lengths.append(steps)
    rewards.append(total_reward)
    
    # Check if the episode is successful
    if total_reward > success_threshold:
        success_count += 1

avg_episode_length = np.mean(episode_lengths)
success_rate = success_count / 100
reward_variance = np.var(rewards)

print(f'Average Episode Length: {avg_episode_length}')
print(f'Success Rate: {success_rate}')
print(f'Reward Variance (Stability): {reward_variance}')
# Out:
# Average Episode Length: 172.28
# Success Rate: 0.67
# Reward Variance (Stability): 18.78

# %% [markdown]
# ### Import Necessary Libraries for Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Visualizations!

# %%
# Visualize Episode Length Distribution
plt.figure(figsize=(10, 6))
plt.hist(episode_lengths, bins=10, color='blue', edgecolor='black', label='Episode Lengths')
plt.title('Episode Length Distribution')
plt.xlabel('Number of Steps')
plt.ylabel('Frequency')
plt.legend(loc='upper right')  # Add legend
plt.show()

# %%
# Visualize Reward Distribution
plt.figure(figsize=(10, 6))
plt.hist(rewards, bins=10, color='green', edgecolor='black', label='Rewards')
plt.title('Reward Distribution')
plt.xlabel('Total Reward per Episode')
plt.ylabel('Frequency')
plt.legend(loc='upper right')  # Add legend
plt.show()

# %%
# Visualize Success Rate (Doughnut Chart)
plt.figure(figsize=(6, 6))
labels = ['Success', 'Failure']
sizes = [success_rate * 100, (1 - success_rate) * 100]
colors = ['lightgreen', 'lightcoral']

# Create a doughnut chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))

# Add a legend
plt.legend(labels, loc='best')

plt.title('Success Rate')
plt.show()

# %%
# Visualize Reward Variance Over Time (Line Chart)
reward_variances = []

for episode in range(100):
    obs = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward

    rewards.append(total_reward)
    if len(rewards) > 1:
        variance = np.var(rewards)
        reward_variances.append(variance)

# Create a line chart for reward variance
plt.figure(figsize=(10, 6))
plt.plot(reward_variances, color='orange', marker='o', label='Reward Variance')
plt.title('Reward Variance Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Reward Variance (points squared)')
plt.grid(True)
plt.legend(loc='upper right')  # Add legend
plt.show()
